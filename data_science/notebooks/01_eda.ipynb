# %% [markdown]
# # 01 – Exploratory Data Analysis (EDA)
#
# **Purpose:** Load expense data from the MySQL `finance_db` mart tables and
# explore distributions, trends, and data quality issues to guide feature
# engineering for Phase 5 forecasting and anomaly detection.
#
# ---
#
# ## Goals
#
# 1. Connect to MySQL using SQLAlchemy and load `mart_monthly_summary`,
#    `mart_category_breakdown`, and `mart_top_merchants`.
# 2. Profile spend distributions by category, merchant, and time period.
# 3. Visualise seasonal patterns using matplotlib / seaborn.
# 4. Identify and document data quality issues (missing values, outliers).
# 5. Generate a summary statistics table for reporting.

# %%
# TODO: Import libraries
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# from sqlalchemy import create_engine
# from dotenv import load_dotenv
# import os

# %%
# TODO: Connect to MySQL
# load_dotenv()
# engine = create_engine(
#     f"mysql+pymysql://{os.getenv('MYSQL_USER')}:{os.getenv('MYSQL_PASSWORD')}"
#     f"@{os.getenv('MYSQL_HOST')}:{os.getenv('MYSQL_PORT', 3306)}/{os.getenv('MYSQL_DATABASE')}"
# )

# %%
# TODO: Load mart tables into DataFrames
# df_monthly = pd.read_sql('SELECT * FROM mart_monthly_summary ORDER BY year, month', engine)
# df_categories = pd.read_sql('SELECT * FROM mart_category_breakdown', engine)
# df_merchants = pd.read_sql('SELECT * FROM mart_top_merchants', engine)

# %%
# TODO: Explore distributions and visualise
# df_monthly.describe()
