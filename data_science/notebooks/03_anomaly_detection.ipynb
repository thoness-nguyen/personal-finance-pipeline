# %% [markdown]
# # 03 – Anomaly Detection
#
# **Purpose:** Identify unusual expense transactions using unsupervised anomaly
# detection techniques. Flagged transactions will be surfaced in the Streamlit
# dashboard (Phase 5, `pages/04_trends.py`).
#
# ---
#
# ## Goals
#
# 1. Load raw `expenses` table from MySQL.
# 2. Engineer features: `amount`, `day_of_week`, `category_id`, rolling spend z-score.
# 3. Apply **Isolation Forest** (`scikit-learn`) to detect outliers.
# 4. Apply **Z-score thresholding** as a simpler baseline method.
# 5. Compare both methods and visualise flagged transactions on a timeline.
# 6. Export anomaly flags back to MySQL (`expenses.needs_cleaning` or a separate
#    `anomalies` table) for downstream use.

# %%
# TODO: Import libraries
# import pandas as pd
# import numpy as np
# from sklearn.ensemble import IsolationForest
# from scipy import stats
# import matplotlib.pyplot as plt
# import seaborn as sns
# from sqlalchemy import create_engine
# from dotenv import load_dotenv
# import os

# %%
# TODO: Load expenses data from MySQL
# df = pd.read_sql('SELECT * FROM expenses WHERE needs_cleaning = FALSE', engine)

# %%
# TODO: Feature engineering
# features = df[['amount', 'category_id']].copy()
# features['day_of_week'] = pd.to_datetime(df['expense_date']).dt.dayofweek

# %%
# TODO: Fit Isolation Forest and predict anomalies
# clf = IsolationForest(contamination=0.05, random_state=42)
# df['anomaly_iforest'] = clf.fit_predict(features)
# # -1 = anomaly, 1 = normal

# %%
# TODO: Z-score baseline
# df['z_score'] = stats.zscore(df['amount'])
# df['anomaly_zscore'] = df['z_score'].abs() > 3

# %%
# TODO: Visualise and export anomaly flags to MySQL
