# %% [markdown]
# # 02 – Monthly Spend Forecasting
#
# **Purpose:** Train a time-series forecasting model on historical monthly spend
# data to predict future expenses. Primary model: **Prophet** (Meta).
# Secondary benchmark: **ARIMA** (statsmodels).
#
# ---
#
# ## Goals
#
# 1. Load `mart_monthly_summary` from MySQL and prepare a Prophet-compatible
#    DataFrame with `ds` (date) and `y` (total_spend) columns.
# 2. Fit a Prophet model with yearly and weekly seasonality.
# 3. Generate a 3-month forward forecast with uncertainty intervals.
# 4. Plot the forecast using Prophet's built-in plot() and plotly.
# 5. (Optional) Fit an ARIMA model and compare RMSE with Prophet.
# 6. Export forecast results to MySQL `predictions` table for Streamlit display.

# %%
# TODO: Import libraries
# import pandas as pd
# from prophet import Prophet
# import matplotlib.pyplot as plt
# from sqlalchemy import create_engine
# from dotenv import load_dotenv
# import os

# %%
# TODO: Load monthly data and prepare for Prophet
# df = pd.read_sql('SELECT * FROM mart_monthly_summary ORDER BY year, month', engine)
# prophet_df = df.rename(columns={'date_key': 'ds', 'total_spend': 'y'})

# %%
# TODO: Fit Prophet model and generate forecast
# model = Prophet(yearly_seasonality=True)
# model.fit(prophet_df)
# future = model.make_future_dataframe(periods=3, freq='MS')
# forecast = model.predict(future)
# model.plot(forecast)

# %%
# TODO: Export forecast to MySQL predictions table
